# %% [markdown]
# <h1>Pandas and matplotlib</h1>
# Pandas is arguably the most used library in data science and most visualisations in python are made using matplotlib. They are also incredibly important to Machine Learning as they allow one to explore the data (and formulate the questions based on it) and also CLEAN/PREPARE the data. It is not an exageration saying that 80-90% of the work done by a Data Scientist is cleaning data.
#
# [pandas](https://pandas.pydata.org/) is a powerful library that allows one to work with data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# To open our dataset let us use [pd.read csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
databreach_df = pd.read_csv('DataBreaches(2004-2021).csv', sep=',')

# %% [markdown]
# Question: df stands for dataframe but what is a dataframe?

# %% [markdown]
# Question: how do we print the dataframe? When is that convenient?

# %%
print(databreach_df)
# Out:
#                                                 Entity  Year    Records  \
# 0                                21st Century Oncology  2016    2200000
# 1                                                500px  2020   14870304
# 2                                Accendo Insurance Co.  2020     175350
# 3                           Adobe Systems Incorporated  2013  152000000
# 4                                           Adobe Inc.  2019    7500000
# ..                                                 ...   ...        ...
# 290                                              Zynga  2019  173000000
# 291                                            Westpac  2019      98000
# 292  Unknown agency(believed to be tied to United S...  2020  200000000
# 293  National Health Information Center (NCZI) of S...  2020     391250
# 294                         Les Éditions Protégez-vous  2020     380000
#
#         Organization type                  Method
# 0              healthcare                  hacked
# 1       social networking                  hacked
# 2              healthcare           poor security
# 3                    tech                  hacked
# 4                    tech           poor security
# ..                    ...                     ...
# 290        social network                  hacked
# 291             financial                  hacked
# 292             financial  accidentally published
# 293            healthcare           poor security
# 294  publisher (magazine)                 unknown
#
# [295 rows x 5 columns]

# %% [markdown]
# Being able to see the entirety of the data on the screen is a double edged sword. In one hand the human working on a given dataset can be there visually inspecting the dataset all the time. On the other hand this process of merely displaying the data can quickly become a burden to the processing time. It is then more practical to use a different approach when dealing with large datasets.<br>
#
# In this sense there are a few tools we can use to inspect the data for example [head](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html) and [tail](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html).

# %%
# Displaying the first 5 rows of the dataframe.
databreach_df.head()
# Out:
#                        Entity  Year    Records  Organization type  \
# 0       21st Century Oncology  2016    2200000         healthcare
# 1                       500px  2020   14870304  social networking
# 2       Accendo Insurance Co.  2020     175350         healthcare
# 3  Adobe Systems Incorporated  2013  152000000               tech
# 4                  Adobe Inc.  2019    7500000               tech
#
#           Method
# 0         hacked
# 1         hacked
# 2  poor security
# 3         hacked
# 4  poor security

# %%
# Displaying the bottom 5 rows of the dataframe.
databreach_df.tail()
# Out:
#                                                 Entity  Year    Records  \
# 290                                              Zynga  2019  173000000
# 291                                            Westpac  2019      98000
# 292  Unknown agency(believed to be tied to United S...  2020  200000000
# 293  National Health Information Center (NCZI) of S...  2020     391250
# 294                         Les Éditions Protégez-vous  2020     380000
#
#         Organization type                  Method
# 290        social network                  hacked
# 291             financial                  hacked
# 292             financial  accidentally published
# 293            healthcare           poor security
# 294  publisher (magazine)                 unknown

# %% [markdown]
# Another very powerful tool is [describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)

# %%
databreach_df.describe()
# Out:
#             Records
# count  2.950000e+02
# mean   4.468863e+07
# std    1.959801e+08
# min    6.700000e+03
# 25%    3.075000e+05
# 50%    2.000000e+06
# 75%    2.000000e+07
# max    3.000000e+09

# %% [markdown]
# Question: what are we seeing above? How is that useful? How is that NOT useful?

# %% [markdown]
# It is also possible to query specific aspects of each individual column. To select only a column it is similar to getting a specific item of a dictionary,

# %%
# Getting only the items that are in the method column.
databreach_df['Method']
# Out:
# 0                      hacked
# 1                      hacked
# 2               poor security
# 3                      hacked
# 4               poor security
#                 ...
# 290                    hacked
# 291                    hacked
# 292    accidentally published
# 293             poor security
# 294                   unknown
# Name: Method, Length: 295, dtype: object

# %%
databreach_df.Method
# Out:
# 0                      hacked
# 1                      hacked
# 2               poor security
# 3                      hacked
# 4               poor security
#                 ...
# 290                    hacked
# 291                    hacked
# 292    accidentally published
# 293             poor security
# 294                   unknown
# Name: Method, Length: 295, dtype: object

# %%
# A list of columns can also be selected.
databreach_df[['Year','Records','Method']]
# Out:
#      Year    Records                  Method
# 0    2016    2200000                  hacked
# 1    2020   14870304                  hacked
# 2    2020     175350           poor security
# 3    2013  152000000                  hacked
# 4    2019    7500000           poor security
# ..    ...        ...                     ...
# 290  2019  173000000                  hacked
# 291  2019      98000                  hacked
# 292  2020  200000000  accidentally published
# 293  2020     391250           poor security
# 294  2020     380000                 unknown
#
# [295 rows x 3 columns]

# %% [markdown]
# To get to know all keys of the dataframe (or for getting something you can quick copy and paste) you can use

# %%
# This also works on dictionaries!
databreach_df.keys()
# Out:
# Index(['Entity', 'Year', 'Records', 'Organization type', 'Method'], dtype='object')

# %%
databreach_df.columns
# Out:
# Index(['Entity', 'Year', 'Records', 'Organization type', 'Method'], dtype='object')

# %% [markdown]
# For non-numerical columns other tools are more appropriated to understand the value distribution, such as

# %%
# This shows all the unique entries in the dataset for that column.
databreach_df['Records'].unique()
# Out:
# array([   2200000,   14870304,     175350,  152000000,    7500000,
#           4000000,      75000,     344579,  320000000,      20000,
#            200000,     300000,   46000000,     156000,   80000000,
#          92000000,   20000000,    2400000,   12367232,     275000,
#             91000,   32000000,     113000,     114000,   18000000,
#            125000,    1220000,     250000,   12500000,    1200000,
#           1900000,     100000,   35040000,    2300000,    7633234,
#          14000000,    1023209,      90000,     500000,     800000,
#         140000000,     350000,  106000000,   40000000,    9400000,
#           1100000,      60000,     110000,    5000000,   56000000,
#           6000000,   10000000,    3900000,     360083,     150000,
#            160000,     105470,    4500000,   55000000,    1000000,
#           2600000,    2500000,      40000,    8637405,    8000000,
#             30000,    9700000,     600000,    4900000,    3000000,
#          68648009,    1400000,  145000000,    2000000,    3300000,
#            514330,  108000000,     251000,     180111,     315000,
#         163119000,   50000000,  340000000,   15000000,  540000000,
#           1500000,  267000000,     461091,     400000,    8500000,
#         885000000,  412214295,     420000,  201000000,    7000000,
#           9000000,      25000,   11100000,    4200000,   28517244,
#            808000,  130000000,     363000,     283000,  200000000,
#            720000,       6700,    1250000,     510000,    1600000,
#          76000000,  100000000,    8700000,     130495,     860000,
#         500000000,    5200000,     210000,  160000000,     780000,
#            102153,  250000000,     163792,      14200,     960000,
#         202000000,  275000000,      34000,      76000,   92283889,
#           1055489,     573000,    1700000,    1800000,      52000,
#          13200000,    8300000,     240000,     430000,    3950000,
#          21500000,    6500000,     760000,     880000,   20076016,
#            123857,   11000000,     515000,   11900000,    1381735,
#          98167935,     680000,     180000,    4600000,     231400,
#           1290755,      50500,     377428,    4700000,   24600000,
#          77000000,      16000,    6400000,      72000,      97000,
#           3500000,   35000000,    6800000,     935000,    4243434,
#           2434899,   28722877,  110000000,       8800,    6300000,
#            260000,     170000,  120000000,      89000,   26151608,
#          28000000,   42000000,   94000000,   17000000,   45000000,
#           4901432,     398000,  299055000,   65469298,      50000,
#          57000000,      84000,   25000000,    1164540,  150000000,
#             80000,      63000,    2100000,      73000,   60000000,
#            392000,   26500000,     123461,     131000,     130000,
#          38000000,     900000,    8257378,     531400,    1300000,
#           1270000,  270000000,   30000000,   43430316,      62000,
#           6054459, 3000000000,   22000000,     450000,      43000,
#          24000000,  173000000,      98000,     391250,     380000])

# %%
databreach_df['Organization type'].value_counts()
# Out:
# Organization type
# web                                                                         49
# healthcare                                                                  45
# financial                                                                   36
# government                                                                  27
# retail                                                                      20
# tech                                                                        14
# telecoms                                                                    12
# academic                                                                    12
# gaming                                                                      10
# social network                                                               8
# military                                                                     6
# transport                                                                    5
# energy                                                                       3
# hotel                                                                        3
# social media                                                                 2
# government, healthcare                                                       2
# media                                                                        2
# tech, retail                                                                 2
# telecommunications                                                           2
# phone accessories                                                            1
# government, database                                                         1
# web, tech                                                                    1
# web, gaming                                                                  1
# market analysis                                                              1
# Consumer Goods                                                               1
# ticket distribution                                                          1
# telecom                                                                      1
# military, healthcare                                                         1
# Telephone directory                                                          1
# Clinical Laboratory                                                          1
# government, military                                                         1
# online marketing                                                             1
# mobile carrier                                                               1
# tech, web                                                                    1
# Question & Answer                                                            1
# local search                                                                 1
# fashion                                                                      1
# QR code payment                                                              1
# advertising                                                                  1
# educational services                                                         1
# banking                                                                      1
# game                                                                         1
# background check                                                             1
# restaurant                                                                   1
# financial, credit reporting                                                  1
# data broker                                                                  1
# financial service company                                                    1
# personal and demographic data about residents and their properties of US     1
# special public corporation                                                   1
# shopping                                                                     1
# social networking                                                            1
# web, military                                                                1
# genealogy                                                                    1
# publisher (magazine)                                                         1
# Name: count, dtype: int64

# %%
databreach_df['Method'].value_counts()
# Out:
# Method
# hacked                                                  156
# poor security                                            36
# lost / stolen media                                      32
# inside job                                               18
# accidentally published                                   17
# lost / stolen computer                                   15
# unknown                                                   4
# improper setting, hacked                                  2
# poor security/inside job                                  2
# intentionally lost                                        1
# accidentally exposed                                      1
# publicly accessible Amazon Web Services (AWS) server      1
# rogue contractor                                          1
# misconfiguration/poor security                            1
# Poor security                                             1
# data exposed by misconfiguration                          1
# unprotected api                                           1
# poor security / hacked                                    1
# accidentally uploaded                                     1
# unsecured S3 bucket                                       1
# inside job, hacked                                        1
# social engineering                                        1
# Name: count, dtype: int64

# %%
# This will count how much incidence of a given unique entry is seen on the dataframe.
databreach_df['Year'].value_counts()
# Out:
# Year
# 2011             33
# 2013             26
# 2019             26
# 2020             24
# 2012             22
# 2018             21
# 2010             19
# 2014             18
# 2015             18
# 2016             17
# 2008             16
# 2009             13
# 2007             12
# 2021              9
# 2005              6
# 2017              6
# 2006              6
# 2018-2019         1
# 2014 and 2015     1
# 2004              1
# Name: count, dtype: int64

# %%
databreach_df['Organization type'].describe()
# Out:
# count     295
# unique     54
# top       web
# freq       49
# Name: Organization type, dtype: object

# %%
databreach_df['Entity'].describe()
# Out:
# count          295
# unique         277
# top       Facebook
# freq             5
# Name: Entity, dtype: object

# %% [markdown]
# Now numbers can be quite confusing and their significance is limited when context or comparissons are not offered. In this sense pandas dataframes also contain many built-in functions that can help you. For example:

# %%
databreach_df['Method'].describe()
# Out:
# count        295
# unique        22
# top       hacked
# freq         156
# Name: Method, dtype: object

# %%
databreach_df.hist()
# Out:
# array([[<Axes: title={'center': 'Records'}>]], dtype=object)

# %% [markdown]
# Exploring the built in histogram method.

# %%
# This plots the histogram of the records column
databreach_df.hist('Records')
# Out:
# array([[<Axes: title={'center': 'Records'}>]], dtype=object)

# %% [markdown]
# Exploring a line plot.

# %%
databreach_df['Records'].plot()
# Out:
# <Axes: >

# %%
databreach_df['Method'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
databreach_df['Year'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
databreach_df.plot.scatter(x='Records',y='Year')
# Out:
# <Axes: xlabel='Records', ylabel='Year'>

# %% [markdown]
# What's the difference between a plot and a scatter plot?

# %%
databreach_df.plot.scatter(x='Records',y='Method')
# Out:
# <Axes: xlabel='Records', ylabel='Method'>

# %%
databreach_df.plot.scatter(x='Year',y='Method')
# Out:
# <Axes: xlabel='Year', ylabel='Method'>

# %%
databreach_df.plot.scatter(x='Year',y='Records')
# Out:
# <Axes: xlabel='Year', ylabel='Records'>
